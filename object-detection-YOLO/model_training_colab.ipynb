# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
# !ls '/content/gdrive/My Drive/alpaca/data'

# %%
root_dir = '/content/gdrive/My Drive/alpaca/data'

# %%
# !pip install ultralytics

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

results = model.train(data=os.path.join(root_dir, "colab_conf.yaml"), epochs = 100)

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/alpaca/data'
